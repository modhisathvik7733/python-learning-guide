# %% [markdown]
# Data preprocessing and feature engineering are closely related, often overlapping steps in machine learning, but they are not the same. Preprocessing focuses on cleaning raw, messy data (e.g., handling missing values, normalization). Feature engineering takes cleaned data to create new, more meaningful input variables that improve model performance

# %% [markdown]
# ![image.png](attachment:b825d339-eb36-453c-a830-3b9741e6bba9.png)
