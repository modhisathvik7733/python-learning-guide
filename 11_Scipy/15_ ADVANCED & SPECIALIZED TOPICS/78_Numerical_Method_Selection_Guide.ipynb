# %% [markdown]
# # Numerical Method Selection Guide
# - Algorithm selection criteria, Performance comparison, Best practices
# - Real examples: Decision trees, Benchmarking

# %%
import numpy as np
from scipy import optimize, integrate, linalg, sparse
import time
print('Method selection guide loaded')
# Out:
# Method selection guide loaded

# %% [markdown]
# ## Integration Method Selection
#
# **Decision factors**:
# - Smoothness of integrand
# - Accuracy requirements
# - Oscillatory behavior
# - Infinite limits

# %%
print('Integration Method Selection\n')

print('METHOD SELECTION GUIDE:\n')
print('1. QUAD (adaptive quadrature)')
print('   ✓ General purpose, smooth functions')
print('   ✓ Automatic error control')
print('   ✓ First choice for most problems\n')

print('2. ROMBERG (Richardson extrapolation)')
print('   ✓ Very smooth functions')
print('   ✓ Higher accuracy')
print('   ✓ Slower than quad\n')

print('3. FIXED_QUAD (Gaussian quadrature)')
print('   ✓ Polynomial-like functions')
print('   ✓ Fixed number of points')
print('   ✓ Fast when function evaluations are cheap\n')

print('4. SIMPSON/TRAPZ (composite rules)')
print('   ✓ Data points given (not function)')
print('   ✓ Simple, fast')
print('   ✓ Lower accuracy\n')

print('5. QUADRATURE (Gaussian, fixed order)')
print('   ✓ Known weights and nodes')
print('   ✓ Fastest for specific cases')
# Out:
# Integration Method Selection
#
# METHOD SELECTION GUIDE:
#
# 1. QUAD (adaptive quadrature)
#    ✓ General purpose, smooth functions
#    ✓ Automatic error control
#    ✓ First choice for most problems
#
# 2. ROMBERG (Richardson extrapolation)
#    ✓ Very smooth functions
#    ✓ Higher accuracy
#    ✓ Slower than quad
#
# 3. FIXED_QUAD (Gaussian quadrature)
#    ✓ Polynomial-like functions
#    ✓ Fixed number of points
#    ✓ Fast when function evaluations are cheap
#
# 4. SIMPSON/TRAPZ (composite rules)
#    ✓ Data points given (not function)
#    ✓ Simple, fast
#    ✓ Lower accuracy
#
# 5. QUADRATURE (Gaussian, fixed order)
#    ✓ Known weights and nodes
#    ✓ Fastest for specific cases

# %%
print('\n\nPERFORMANCE COMPARISON\n')

def f(x):
    return np.exp(-x**2)

methods = [
    ('quad', lambda: integrate.quad(f, 0, 2)),
    ('romberg', lambda: integrate.romberg(f, 0, 2)),
    ('fixed_quad', lambda: integrate.fixed_quad(f, 0, 2, n=5))
]

for name, method in methods:
    start = time.time()
    result, *_ = method()
    elapsed = (time.time() - start) * 1e6
    
    print(f'{name:12s}: {result:.10f}  ({elapsed:.1f} µs)')

print('\nAll methods agree to high precision!')
# Out:
# PERFORMANCE COMPARISON
#
# quad        : 0.8820813908  (82.3 µs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 14
#      12 for name, method in methods:
#      13     start = time.time()
# ---> 14     result, *_ = method()
#      15     elapsed = (time.time() - start) * 1e6
#      17     print(f'{name:12s}: {result:.10f}  ({elapsed:.1f} µs)')
#
# Cell In[3], line 8, in <lambda>()
#       3 def f(x):
#       4     return np.exp(-x**2)
#       6 methods = [
#       7     ('quad', lambda: integrate.quad(f, 0, 2)),
# ----> 8     ('romberg', lambda: integrate.romberg(f, 0, 2)),
#       9     ('fixed_quad', lambda: integrate.fixed_quad(f, 0, 2, n=5))
#      10 ]
#      12 for name, method in methods:
#      13     start = time.time()
#
# AttributeError: module 'scipy.integrate' has no attribute 'romberg'

# %% [markdown]
# ## Optimization Method Selection
#
# **Decision tree**:
# 1. Derivatives available? → Use gradient methods
# 2. Constraints? → Choose appropriate solver
# 3. Global minimum? → Use global methods

# %%
print('\nOptimization Method Selection\n')

print('DECISION TREE:\n')
print('┌─ Do you have derivatives?')
print('│')
print('├─ YES → Use gradient-based methods')
print('│   ├─ Unconstrained: BFGS, L-BFGS-B')
print('│   ├─ Box constraints: L-BFGS-B')
print('│   └─ General constraints: SLSQP, trust-constr')
print('│')
print('└─ NO → Use derivative-free methods')
print('    ├─ Smooth function: Nelder-Mead, Powell')
print('    ├─ Noisy function: Nelder-Mead')
print('    └─ Global search: differential_evolution\n')

print('SPECIAL CASES:\n')
print('• Least squares → leastsq, least_squares')
print('• Linear programming → linprog')
print('• Quadratic programming → quadratic_assignment')
print('• Root finding → root, fsolve')
print('• Global optimization → differential_evolution, basinhopping')

# %%
print('\n\nMETHOD COMPARISON EXAMPLE\n')

def rosenbrock(x):
    return sum(100.0*(x[1:]-x[:-1]**2)**2 + (1-x[:-1])**2)

x0 = np.array([0, 0])

methods = ['Nelder-Mead', 'Powell', 'BFGS', 'L-BFGS-B']

print('Minimizing Rosenbrock function:\n')
for method in methods:
    start = time.time()
    result = optimize.minimize(rosenbrock, x0, method=method)
    elapsed = (time.time() - start) * 1000
    
    print(f'{method:12s}: f={result.fun:.2e}, nfev={result.nfev:3d}, time={elapsed:.2f}ms')

print('\nBFGS fastest for smooth functions with gradients')

# %% [markdown]
# ## Linear Algebra Method Selection
#
# **Key factors**:
# - Matrix properties (symmetric, positive definite, sparse)
# - Size
# - Condition number

# %%
print('\nLinear Algebra Method Selection\n')

print('MATRIX SOLUTION (Ax = b):\n')
print('1. DENSE MATRICES')
print('   ├─ General: linalg.solve(A, b)')
print('   ├─ Symmetric: linalg.solve(A, b, assume_a=\'pos\')')
print('   ├─ Triangular: linalg.solve_triangular(A, b)')
print('   └─ Banded: linalg.solve_banded(...)\n')

print('2. SPARSE MATRICES')
print('   ├─ Direct: sparse.linalg.spsolve(A, b)')
print('   ├─ Iterative (large): sparse.linalg.cg(A, b)')
print('   ├─ Iterative (general): sparse.linalg.gmres(A, b)')
print('   └─ Symmetric: sparse.linalg.minres(A, b)\n')

print('EIGENVALUE PROBLEMS:\n')
print('Dense:')
print('  • All: linalg.eig(A)')
print('  • Symmetric: linalg.eigh(A) [faster]')
print('  • Generalized: linalg.eig(A, B)\n')
print('Sparse:')
print('  • Few eigenvalues: sparse.linalg.eigs(A, k=10)')
print('  • Symmetric: sparse.linalg.eigsh(A, k=10) [faster]')

# %%
print('\n\nPERFORMANCE: Dense vs Sparse\n')

n = 1000

# Dense matrix
A_dense = np.random.rand(n, n)
b_dense = np.random.rand(n)

start = time.time()
x_dense = linalg.solve(A_dense, b_dense)
time_dense = (time.time() - start) * 1000

# Sparse matrix (tridiagonal)
diag = np.ones(n) * 2
off_diag = -np.ones(n-1)
A_sparse = sparse.diags([off_diag, diag, off_diag], [-1, 0, 1], format='csr')
b_sparse = np.random.rand(n)

start = time.time()
x_sparse = sparse.linalg.spsolve(A_sparse, b_sparse)
time_sparse = (time.time() - start) * 1000

print(f'Matrix size: {n}×{n}\n')
print(f'Dense solver: {time_dense:.2f} ms')
print(f'Sparse solver: {time_sparse:.2f} ms')
print(f'\nSpeedup: {time_dense/time_sparse:.1f}x faster for sparse!')

# %% [markdown]
# ## Statistical Test Selection
#
# **Decision factors**:
# - Data distribution (normal vs non-normal)
# - Sample size
# - Number of groups
# - Paired vs independent

# %%
print('\nStatistical Test Selection\n')

print('COMPARING TWO GROUPS:\n')
print('┌─ Are data normally distributed?')
print('│')
print('├─ YES (normal) →')
print('│   ├─ Independent samples: t-test (ttest_ind)')
print('│   └─ Paired samples: paired t-test (ttest_rel)')
print('│')
print('└─ NO (non-normal) →')
print('    ├─ Independent: Mann-Whitney U (mannwhitneyu)')
print('    └─ Paired: Wilcoxon signed-rank (wilcoxon)\n')

print('COMPARING 3+ GROUPS:\n')
print('┌─ Normal data?')
print('│')
print('├─ YES → One-way ANOVA (f_oneway)')
print('│   └─ Post-hoc: Tukey HSD')
print('│')
print('└─ NO → Kruskal-Wallis H (kruskal)')
print('    └─ Post-hoc: Dunn test\n')

print('CATEGORICAL DATA:\n')
print('• Contingency table: Chi-square (chi2_contingency)')
print('• Goodness of fit: Chi-square (chisquare)')
print('• Proportions: Z-test (proportions_ztest)')

# %% [markdown]
# ## Best Practices Summary
#
# **General principles**:
# 1. Start simple, increase complexity if needed
# 2. Leverage problem structure (symmetry, sparsity)
# 3. Profile before optimizing
# 4. Use analytical derivatives when possible
# 5. Validate results

# %%
print('\nNumerical Computing Best Practices\n')

print('1. NUMERICAL STABILITY')
print('   ✓ Avoid subtracting nearly equal numbers')
print('   ✓ Scale variables to similar magnitudes')
print('   ✓ Use stable algorithms (QR vs normal equations)\n')

print('2. PERFORMANCE')
print('   ✓ Vectorize operations (avoid loops)')
print('   ✓ Use appropriate data structures (sparse for sparse)')
print('   ✓ Profile before optimizing')
print('   ✓ Consider memory vs speed tradeoffs\n')

print('3. ACCURACY')
print('   ✓ Check condition numbers')
print('   ✓ Use appropriate tolerances')
print('   ✓ Verify convergence')
print('   ✓ Compare multiple methods\n')

print('4. ROBUSTNESS')
print('   ✓ Handle edge cases')
print('   ✓ Validate inputs')
print('   ✓ Check for convergence failures')
print('   ✓ Provide informative error messages\n')

print('5. REPRODUCIBILITY')
print('   ✓ Set random seeds')
print('   ✓ Document algorithm choices')
print('   ✓ Record scipy version')
print('   ✓ Save configuration parameters')

# %% [markdown]
# ## Quick Reference Cards
#
# **Integration**: quad → smooth, romberg → very smooth, simpson → data points
#
# **Optimization**: BFGS → smooth+gradient, Nelder-Mead → no gradient, DE → global
#
# **Linear Algebra**: solve → dense, spsolve → sparse, eigh → symmetric eigenvalues
#
# **Statistics**: t-test → normal, Mann-Whitney → non-normal, chi-square → categorical
#
# **Signal**: butter → general filter, savgol → preserve features, welch → PSD
#
# **Sparse**: csr → arithmetic, lil → construction, coo → creation

# %%
print('\nCONGRATULATIONS!\n')
print('='*60)
print('You have completed the SciPy Mastery Series!')
print('='*60)
print()
print('You now have expertise in:')
print('  ✓ Numerical integration and differentiation')
print('  ✓ Optimization and root finding')
print('  ✓ Linear algebra and sparse matrices')
print('  ✓ Statistical analysis and hypothesis testing')
print('  ✓ Signal and image processing')
print('  ✓ Clustering and spatial algorithms')
print('  ✓ Special functions')
print('  ✓ File I/O and data formats')
print('  ✓ Advanced methods (ODR, QMC, etc.)')
print()
print('Next steps:')
print('  1. Apply to your own problems')
print('  2. Explore scipy documentation')
print('  3. Read research papers on algorithms')
print('  4. Contribute to open source!')
print()
print('='*60)
print('Happy Scientific Computing! 🚀')
print('='*60)
