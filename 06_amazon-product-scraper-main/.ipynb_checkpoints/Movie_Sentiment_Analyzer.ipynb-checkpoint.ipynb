# %%
# install required packages
# !pip install beautifulsoup4 requests pandas numpy matplotlib seaborn nltk textblob wordcloud scikit-learn

# %%
# Import necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
import nltk
from wordcloud import WordCloud
import warnings
warnings.filterwarnings('ignore')

nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('stopwords')

from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/chintu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/chintu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chintu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def scrape_imdb_reviews(movie_id, num_pages=3):
    """
    Scrape movie reviews from IMDb
    movie_id: IMDb movie ID (e.g., 'tt4154796' for Avengers: Endgame)
    num_pages: number of pages to scrape
    """

    reviews = []
    ratings = []
